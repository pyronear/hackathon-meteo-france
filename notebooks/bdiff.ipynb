# %%
import pandas as pd

PATH="/Users/alexiscruveiller/Desktop/git/hackathon-meteo-france/data/raw/incendies.csv"

wildfire = pd.read_csv(PATH, sep=";")

# %%
wildfire
# Out:
#        Année  Numéro Département Code INSEE       Nom de la commune  \
# 0       2019   12254          2A      2A200                 Palneca
# 1       2019    7928          2B      2B235               Pioggiola
# 2       2019    8514          11      11401                  Tuchan
# 3       2019    1690          15      15208  Saint-Projet-de-Salers
# 4       2019    1691          15      15070               Fontanges
# ...      ...     ...         ...        ...                     ...
# 12655   2022   11134          64      64545                 Urrugne
# 12656   2022   21656          66      66192                   Sauto
# 12657   2022   21658          66      66118                 Montner
# 12658   2022   12005          33      33051                 Biganos
# 12659   2022   21725          2A      2A048             Calcatoggio
#
#       Date de première alerte Origine de l'alerte  \
# 0            01/01/2019 21:14         Indéterminé
# ...
