# %%
# Imports
import geopandas as gpd
import json

# %%
gdf_carro_dfci = gpd.read_file("/Users/camillemodeste/Documents/Workflow/Pyronear/hackathon-meteo-france/data/raw/CARRO_DFCI_2X2_L93.shp",crs="EPSG:2154")

# %%
print(gdf_carro_dfci.crs)
# Out:
# EPSG:2154

# %%
gdf_carro_dfci = gdf_carro_dfci.to_crs(4326)

# %%
gdf_carro_dfci
# Out:
#            NOM                                           geometry
# 0       AA40D0  POLYGON ((-4.14819 40.30642, -4.15012 40.32426...
# 1       AA40D1  POLYGON ((-4.15012 40.32426, -4.15205 40.34210...
# 2       AA40D2  POLYGON ((-4.15205 40.34210, -4.15398 40.35994...
# 3       AA40D3  POLYGON ((-4.15398 40.35994, -4.15591 40.37779...
# 4       AA40D4  POLYGON ((-4.15591 40.37779, -4.15784 40.39563...
# ...        ...                                                ...
# 339259  NN86K4  POLYGON ((10.77270 50.71789, 10.77573 50.73573...
# 339260  NN86K5  POLYGON ((10.77573 50.73573, 10.77876 50.75356...
# 339261  NN86K6  POLYGON ((10.77876 50.75356, 10.78179 50.77139...
# 339262  NN86K7  POLYGON ((10.78179 50.77139, 10.78483 50.78923...
# 339263  NN86K8  POLYGON ((10.78483 50.78923, 10.78787 50.80706...
#
# [339264 rows x 2 columns]

# %%
gdf_carro_dfci.plot()
# Out:
# <Axes: >

# %%
gdf_carro_dfci.to_file('/Users/camillemodeste/Documents/Workflow/Pyronear/hackathon-meteo-france/data/processed/carro_dfci_wsg84.geojson', driver="GeoJSON")
